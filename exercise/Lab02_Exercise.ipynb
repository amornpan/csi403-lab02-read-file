# %% [markdown]
# # Lab 02: Reading Markdown Files - Exercise
#
# ## Loading Documents for RAG Systems
#
# ---
#
# **Instructions:**
# 1. Complete all 4 exercises below
# 2. Replace `# YOUR CODE HERE` with your code
# 3. Run each cell to check your structure
# 4. Push to GitHub for auto-grading
#
# **Total Points:** 100 (25 points each)
#
# **Time:** ~45 minutes
#
# ---

# %% [markdown]
# ## Exercise 1: Read File Content (25 points)
#
# Read the content of `../data/rubella.md` and store it in a variable called `file_content`.
#
# Use:
# - `open()` with encoding `utf-8`
# - `with` statement
# - `read()` method

# %%
# Exercise 1: Read the file content
# YOUR CODE HERE

file_content = None  # Replace with your code

# Check your answer
print(f"Content type: {type(file_content)}")
print(f"First 100 characters: {file_content[:100] if file_content else 'None'}")

# %%
# Quick check (structure only)
if file_content is not None:
    print(f"✅ file_content has a value")
    print(f"   Type: {type(file_content).__name__}")
    print(f"   Length: {len(file_content)} characters")
else:
    print("❌ file_content is still None")

# %% [markdown]
# ---
#
# ## Exercise 2: Count Characters (25 points)
#
# Create a variable called `char_count` that contains the total number of characters in `file_content`.
#
# Use `len()` function.

# %%
# Exercise 2: Count total characters
# YOUR CODE HERE

char_count = None  # Replace with your code

# Check your answer
print(f"Total characters: {char_count}")

# %%
# Quick check (structure only)
if char_count is not None:
    print(f"✅ char_count has a value")
    print(f"   Type: {type(char_count).__name__}")
    if isinstance(char_count, int):
        print(f"✅ char_count is an integer")
    else:
        print(f"❌ char_count should be an integer")
else:
    print("❌ char_count is still None")

# %% [markdown]
# ---
#
# ## Exercise 3: Count Lines (25 points)
#
# Create a variable called `line_count` that contains the total number of lines in `file_content`.
#
# Hint: Use `split("\n")` and `len()`

# %%
# Exercise 3: Count total lines
# YOUR CODE HERE

line_count = None  # Replace with your code

# Check your answer
print(f"Total lines: {line_count}")

# %%
# Quick check (structure only)
if line_count is not None:
    print(f"✅ line_count has a value")
    print(f"   Type: {type(line_count).__name__}")
    if isinstance(line_count, int):
        print(f"✅ line_count is an integer")
    else:
        print(f"❌ line_count should be an integer")
else:
    print("❌ line_count is still None")

# %% [markdown]
# ---
#
# ## Exercise 4: Find Text in File (25 points)
#
# Create a variable called `symptom_count` that contains the number of times the word "symptom" appears in the file.
#
# **Important:** Make the search case-insensitive (count both "Symptom" and "symptom").
#
# Hint: Use `.lower()` and `.count()`

# %%
# Exercise 4: Count occurrences of "symptom" (case-insensitive)
# YOUR CODE HERE

symptom_count = None  # Replace with your code

# Check your answer
print(f"'symptom' appears {symptom_count} times")

# %%
# Quick check (structure only)
if symptom_count is not None:
    print(f"✅ symptom_count has a value")
    print(f"   Type: {type(symptom_count).__name__}")
    if isinstance(symptom_count, int):
        print(f"✅ symptom_count is an integer")
    else:
        print(f"❌ symptom_count should be an integer")
else:
    print("❌ symptom_count is still None")

# %% [markdown]
# ---
#
# ## 🎉 Finished!
#
# ### Summary:
#
# | Exercise | Skill |
# |----------|-------|
# | 1 | Read file with `open()` and `read()` |
# | 2 | Count characters with `len()` |
# | 3 | Count lines with `split()` |
# | 4 | Search text with `count()` |
#
# ### Submit:
# ```bash
# git add .
# git commit -m "Complete Lab 02"
# git push
# ```
#
# Check your score in GitHub Actions tab!
